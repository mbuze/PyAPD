# %%
# !pip install petsc petsc4py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached petsc-3.19.2.tar.gz (16.6 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached petsc4py-3.19.2.tar.gz (292 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [65 lines of output]
#       running egg_info
#       creating /tmp/pip-pip-egg-info-erqzsb_1/petsc4py.egg-info
#       writing /tmp/pip-pip-egg-info-erqzsb_1/petsc4py.egg-info/PKG-INFO
#       writing dependency_links to /tmp/pip-pip-egg-info-erqzsb_1/petsc4py.egg-info/dependency_links.txt
#       writing requirements to /tmp/pip-pip-egg-info-erqzsb_1/petsc4py.egg-info/requires.txt
#       writing top-level names to /tmp/pip-pip-egg-info-erqzsb_1/petsc4py.egg-info/top_level.txt
#       writing manifest file '/tmp/pip-pip-egg-info-erqzsb_1/petsc4py.egg-info/SOURCES.txt'
# ...

# %%
# !pip install pysdot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pysdot-0.2.11.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [53 lines of output]
#       =============================== include_dirs ============================= ['ext/eigen3', 'ext/pybind11/include', '/usr/share/miniconda/envs/test/include', '$PREFIX/include', '$CONDA_PREFIX/include', '/usr/include']
#       running bdist_wheel
#       running build
#       running build_py
#       Cloning into 'ext/sdot'...
#       Cloning into 'ext/eigen3'...
#       error: RPC failed; curl 56 OpenSSL SSL_read: Connection reset by peer, errno 104
#       error: 1014 bytes of body are still expected
#       fetch-pack: unexpected disconnect while reading sideband packet
#       fatal: early EOF
#       fatal: fetch-pack: invalid index-pack output
# ...
